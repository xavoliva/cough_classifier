# %% [markdown]
# ### Import libraries

# %%
from IPython.core.display import display
from src.utils.preprocessing import preprocessing_pipeline
from src.utils.get_data import import_data, split_experts
from src.utils.train import hyperparameter_tuning_cv
from src.utils.config import *
import pandas as pd
import numpy as np

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Load Data

# %%
DATA_PATH = '../../../data'
X_no, y_no = import_data(DATA_PATH, segmentation_type='no',
                         drop_user_features=True,
                         drop_expert=True)

# %%
# For each expert separately
X_no_e, y_no_e = import_data(DATA_PATH, segmentation_type='no',
                             drop_user_features=True,
                             drop_expert=False)

# %%
display(X_no.head())
display(y_no.head())
# Out:
#                                       EEPD50_100  EEPD100_150  EEPD150_200  \
# subject
# 008ba489-31ad-44d8-856b-fcf72369dc46        72.0         73.0         71.0
# 008c1c9e-aeef-40c5-846c-24f1b964f884        86.0         87.0         86.0
# 00bf9f83-2e8f-47cf-a4f2-97f2beceebc1        17.0         17.0         17.0
# 018b40a1-c109-459a-9e31-86cbd2cb3918        72.0         73.0         64.0
# 01bf156f-a8ff-48f6-9335-8a1f5bb4c1b7        64.0         65.0         66.0
#
#                                       EEPD200_250  EEPD250_300  EEPD300_350  \
# subject
# 008ba489-31ad-44d8-856b-fcf72369dc46         70.0         69.0         71.0
# 008c1c9e-aeef-40c5-846c-24f1b964f884         83.0         82.0         80.0
# 00bf9f83-2e8f-47cf-a4f2-97f2beceebc1         19.0         19.0         20.0
# 018b40a1-c109-459a-9e31-86cbd2cb3918         66.0         70.0         66.0
# 01bf156f-a8ff-48f6-9335-8a1f5bb4c1b7         69.0         67.0         70.0
#
#                                       EEPD350_400  EEPD400_450  EEPD450_500  \
# subject
# 008ba489-31ad-44d8-856b-fcf72369dc46         70.0         72.0         71.0
# 008c1c9e-aeef-40c5-846c-24f1b964f884         82.0         79.0         74.0
# 00bf9f83-2e8f-47cf-a4f2-97f2beceebc1         19.0         20.0         21.0
# 018b40a1-c109-459a-9e31-86cbd2cb3918         65.0         65.0         70.0
# 01bf156f-a8ff-48f6-9335-8a1f5bb4c1b7         64.0         69.0         66.0
#
#                                       EEPD500_550  ...  MFCC_std12  \
# subject                                            ...
# 008ba489-31ad-44d8-856b-fcf72369dc46         72.0  ...    9.644575
# 008c1c9e-aeef-40c5-846c-24f1b964f884         78.0  ...    8.110090
# 00bf9f83-2e8f-47cf-a4f2-97f2beceebc1         17.0  ...    9.753122
# 018b40a1-c109-459a-9e31-86cbd2cb3918         68.0  ...   10.005029
# 01bf156f-a8ff-48f6-9335-8a1f5bb4c1b7         65.0  ...   15.789141
#
#                                       Crest_Factor  Cough_Length        SNR  \
# subject
# 008ba489-31ad-44d8-856b-fcf72369dc46     21.396543          9.78  17.331636
# 008c1c9e-aeef-40c5-846c-24f1b964f884     11.509653          9.96  48.925328
# 00bf9f83-2e8f-47cf-a4f2-97f2beceebc1      7.536316          2.76  39.487579
# 018b40a1-c109-459a-9e31-86cbd2cb3918     14.964056          9.78  17.963939
# 01bf156f-a8ff-48f6-9335-8a1f5bb4c1b7      8.150607          9.78  21.886511
#
#                                       PSD_225-425  PSD_450-550  PSD_1325-1600  \
# subject
# 008ba489-31ad-44d8-856b-fcf72369dc46     0.274024     0.072153       0.017824
# 008c1c9e-aeef-40c5-846c-24f1b964f884     0.102350     0.054859       0.037391
# 00bf9f83-2e8f-47cf-a4f2-97f2beceebc1     0.302548     0.069098       0.021297
# 018b40a1-c109-459a-9e31-86cbd2cb3918     0.273720     0.067828       0.073858
# 01bf156f-a8ff-48f6-9335-8a1f5bb4c1b7     0.334480     0.031282       0.054040
#
#                                       PSD_1600-2000  PSD_2500-2900  \
# subject
# 008ba489-31ad-44d8-856b-fcf72369dc46       0.024982       0.041253
# 008c1c9e-aeef-40c5-846c-24f1b964f884       0.036934       0.032164
# 00bf9f83-2e8f-47cf-a4f2-97f2beceebc1       0.008322       0.002345
# 018b40a1-c109-459a-9e31-86cbd2cb3918       0.057807       0.022392
# 01bf156f-a8ff-48f6-9335-8a1f5bb4c1b7       0.087913       0.011978
#
#                                       PSD_3100-3700
# subject
# 008ba489-31ad-44d8-856b-fcf72369dc46       0.008166
# 008c1c9e-aeef-40c5-846c-24f1b964f884       0.044875
# 00bf9f83-2e8f-47cf-a4f2-97f2beceebc1       0.003803
# 018b40a1-c109-459a-9e31-86cbd2cb3918       0.028218
# 01bf156f-a8ff-48f6-9335-8a1f5bb4c1b7       0.012351
#
# [5 rows x 67 columns]
#                                       Label
# subject
# 008ba489-31ad-44d8-856b-fcf72369dc46    1.0
# 008c1c9e-aeef-40c5-846c-24f1b964f884    1.0
# 00bf9f83-2e8f-47cf-a4f2-97f2beceebc1    1.0
# 018b40a1-c109-459a-9e31-86cbd2cb3918    1.0
# 01bf156f-a8ff-48f6-9335-8a1f5bb4c1b7    1.0

# %% [markdown]
# ### Preprocessing

# %%
X_no = preprocessing_pipeline(X_no, stop=None, dummy=False)

# %%
# Save the expert feature for split
expert = X_no_e['Expert'].copy()
X_no_e = preprocessing_pipeline(X_no_e, stop=None, dummy=False)
X_no_e['Expert'] = expert.values

# %% [markdown]
# ### Split expert models

# %%
X_no_e_1, y_no_e_1, X_no_e_2, y_no_e_2, X_no_e_3, y_no_e_3 = split_experts(
    X_no_e, y_no_e)

# %% [markdown]
# ### Grid search one model for all

# %%
DECISION_METRIC = 'roc_auc_score'
CV_K = 10

# %% [markdown]
# #### 1. Logistic regression

# %%
log_results = hyperparameter_tuning_cv(model='logistic', data=X_no, labels=y_no.Label, cv_k=CV_K,
                                       params=LOGISTIC_PARAMS)

display(log_results)
# Out:
#                        f1_score  roc_auc_score  roc_auc_score_var  \
# max_iter oversampling
# 10000    True          0.416772       0.583838           0.000471
#          False         0.143273       0.520265           0.000146
# 100000   True          0.416772       0.583838           0.000471
#          False         0.143273       0.520265           0.000146
#
#                        accuracy_score  explained_variance_score
# max_iter oversampling
# 10000    True                 0.59257                 -0.953599
#          False                0.72992                 -0.204322
# 100000   True                 0.59257                 -0.953599
#          False                0.72992                 -0.204322

# %%
# Best model parameters

best_log = log_results.iloc[[
    log_results.reset_index()[DECISION_METRIC].idxmax()]]

display(best_log)
# Out:
#                        f1_score  roc_auc_score  roc_auc_score_var  \
# max_iter oversampling
# 10000    True          0.416772       0.583838           0.000471
#
#                        accuracy_score  explained_variance_score
# max_iter oversampling
# 10000    True                 0.59257                 -0.953599

# %%
# for each expert
log_results_1 = hyperparameter_tuning_cv(model='logistic', data=X_no_e_1, labels=y_no_e_1, cv_k=CV_K,
                                         params=LOGISTIC_PARAMS)
log_results_2 = hyperparameter_tuning_cv(model='logistic', data=X_no_e_2, labels=y_no_e_2, cv_k=CV_K,
                                         params=LOGISTIC_PARAMS)
log_results_3 = hyperparameter_tuning_cv(model='logistic', data=X_no_e_3, labels=y_no_e_3, cv_k=CV_K,
                                         params=LOGISTIC_PARAMS)

# %%
# Best model parameters

best_log_1 = log_results_1.iloc[[
    log_results_1.reset_index()[DECISION_METRIC].idxmax()]]
best_log_2 = log_results_2.iloc[[
    log_results_2.reset_index()[DECISION_METRIC].idxmax()]]
best_log_3 = log_results_3.iloc[[
    log_results_3.reset_index()[DECISION_METRIC].idxmax()]]

display(best_log_1, best_log_2, best_log_3)
# Out:
#                        f1_score  roc_auc_score  roc_auc_score_var  \
# max_iter oversampling
# 10000    True          0.357511       0.650937           0.000831
#
#                        accuracy_score  explained_variance_score
# max_iter oversampling
# 10000    True                0.728667                 -1.086077
#                        f1_score  roc_auc_score  roc_auc_score_var  \
# max_iter oversampling
# 10000    True          0.242599       0.502561           0.000622
#
#                        accuracy_score  explained_variance_score
# max_iter oversampling
# 10000    True                0.576344                  -1.61354
#                        f1_score  roc_auc_score  roc_auc_score_var  \
# max_iter oversampling
# 10000    True          0.568719       0.602656           0.001133
#
#                        accuracy_score  explained_variance_score
# max_iter oversampling
# 10000    True                0.603049                 -0.588149

# %% [markdown]
# #### 2. Linear Discriminant Analysis

# %%
lda_results = hyperparameter_tuning_cv(model='lda', data=X_no, labels=y_no.Label, cv_k=CV_K,
                                       params=LDA_PARAMS)

display(lda_results)
# Out:
#               f1_score  roc_auc_score  roc_auc_score_var  accuracy_score  \
# oversampling
# True          0.417288       0.582798           0.000405        0.585341
# False         0.137679       0.518028           0.000156        0.728112
#
#               explained_variance_score
# oversampling
# True                         -0.964809
# False                        -0.213875

# %%
# Best model parameters

best_lda = lda_results.iloc[[
    lda_results.reset_index()[DECISION_METRIC].idxmax()]]

display(best_lda)
# Out:
#               f1_score  roc_auc_score  roc_auc_score_var  accuracy_score  \
# oversampling
# True          0.417288       0.582798           0.000405        0.585341
#
#               explained_variance_score
# oversampling
# True                         -0.964809

# %%
# For each expert
lda_results_1 = hyperparameter_tuning_cv(model='lda', data=X_no_e_1, labels=y_no_e_1, cv_k=CV_K,
                                         params=LDA_PARAMS)
lda_results_2 = hyperparameter_tuning_cv(model='lda', data=X_no_e_2, labels=y_no_e_2, cv_k=CV_K,
                                         params=LDA_PARAMS)
lda_results_3 = hyperparameter_tuning_cv(model='lda', data=X_no_e_3, labels=y_no_e_3, cv_k=CV_K,
                                         params=LDA_PARAMS)

# %%
best_lda_1 = lda_results_1.iloc[[
    lda_results_1.reset_index()[DECISION_METRIC].idxmax()]]
best_lda_2 = lda_results_2.iloc[[
    lda_results_2.reset_index()[DECISION_METRIC].idxmax()]]
best_lda_3 = lda_results_3.iloc[[
    lda_results_3.reset_index()[DECISION_METRIC].idxmax()]]

display(best_lda_1, best_lda_2, best_lda_3)
# Out:
#               f1_score  roc_auc_score  roc_auc_score_var  accuracy_score  \
# oversampling
# True          0.361813       0.661555           0.001107        0.702667
#
#               explained_variance_score
# oversampling
# True                         -1.194513
#               f1_score  roc_auc_score  roc_auc_score_var  accuracy_score  \
# oversampling
# True           0.23956       0.493704           0.001042        0.554839
#
#               explained_variance_score
# oversampling
# True                         -1.688357
#               f1_score  roc_auc_score  roc_auc_score_var  accuracy_score  \
# oversampling
# True          0.569139       0.597456            0.00105        0.596951
#
#               explained_variance_score
# oversampling
# True                         -0.610307

# %% [markdown]
# #### 3. K-nearest Neighbors

# %%
knn_results = hyperparameter_tuning_cv(model='knn', data=X_no, labels=y_no.Label, cv_k=CV_K,
                                       params=KNN_PARAMS)

display(knn_results)
# Out:
#                           f1_score  roc_auc_score  roc_auc_score_var  \
# n_neighbors oversampling
# 1           True          0.367647       0.534884           0.000375
#             False         0.311914       0.529891           0.000397
# 2           True          0.345884       0.537181           0.000259
#             False         0.140978       0.509421           0.000135
# 3           True          0.401640       0.549222           0.000097
#             False         0.258390       0.522913           0.000129
# 4           True          0.383645       0.545418           0.000037
#             False         0.150953       0.513616           0.000100
# 5           True          0.401660       0.542200           0.000245
#             False         0.238438       0.527352           0.000384
# 6           True          0.396293       0.546145           0.000191
#             False         0.138070       0.511414           0.000108
# 7           True          0.408890       0.545639           0.000336
#             False         0.204024       0.519351           0.000082
# 8           True          0.403046       0.547802           0.000428
#             False         0.133205       0.511629           0.000162
# 9           True          0.412217       0.547008           0.000434
#             False         0.189755       0.520493           0.000194
# 10          True          0.409420       0.551091           0.000605
#             False         0.126094       0.514262           0.000089
# 11          True          0.413194       0.546315           0.000609
#             False         0.163756       0.518596           0.000150
# 12          True          0.410915       0.549290           0.000677
#             False         0.120617       0.516404           0.000061
# 13          True          0.418363       0.551580           0.000357
#             False         0.161923       0.521399           0.000134
# 14          True          0.419286       0.558399           0.000340
#             False         0.095236       0.510120           0.000131
# 15          True          0.421583       0.554180           0.000328
#             False         0.132097       0.515574           0.000221
#
#                           accuracy_score  explained_variance_score
# n_neighbors oversampling
# 1           True                0.543976                 -1.160033
#             False               0.627108                 -0.944095
# 2           True                0.595783                 -1.056824
#             False               0.711446                 -0.342575
# 3           True                0.495783                 -1.068674
#             False               0.665663                 -0.722917
# 4           True                0.538153                 -1.122078
#             False               0.714257                 -0.327716
# 5           True                0.468474                 -1.047280
#             False               0.690763                 -0.552990
# 6           True                0.503815                 -1.098936
#             False               0.715863                 -0.306206
# 7           True                0.455422                 -0.982206
#             False               0.697390                 -0.487448
# 8           True                0.487550                 -1.059944
#             False               0.718675                 -0.281977
# 9           True                0.446386                 -0.938614
#             False               0.708032                 -0.401607
# 10          True                0.476104                 -1.010304
#             False               0.726104                 -0.220269
# 11          True                0.439558                 -0.916298
#             False               0.717269                 -0.314008
# 12          True                0.463454                 -0.984736
#             False               0.731928                 -0.171217
# 13          True                0.438755                 -0.874193
#             False               0.723293                 -0.268519
# 14          True                0.465462                 -0.931538
#             False               0.730723                 -0.161848
# 15          True                0.435341                 -0.838540
#             False               0.725904                 -0.226831

# %%
# Best model parameters

best_knn = knn_results.iloc[[
    knn_results.reset_index()[DECISION_METRIC].idxmax()]]

display(best_knn)
# Out:
#                           f1_score  roc_auc_score  roc_auc_score_var  \
# n_neighbors oversampling
# 14          True          0.419286       0.558399            0.00034
#
#                           accuracy_score  explained_variance_score
# n_neighbors oversampling
# 14          True                0.465462                 -0.931538

# %%
knn_results_1 = hyperparameter_tuning_cv(
    model='knn', data=X_no_e_1, labels=y_no_e_1, cv_k=CV_K, params=KNN_PARAMS)
knn_results_2 = hyperparameter_tuning_cv(
    model='knn', data=X_no_e_2, labels=y_no_e_2, cv_k=CV_K, params=KNN_PARAMS)
knn_results_3 = hyperparameter_tuning_cv(
    model='knn', data=X_no_e_3, labels=y_no_e_3, cv_k=CV_K, params=KNN_PARAMS)

# %%
best_knn_1 = knn_results_1.iloc[[
    knn_results_1.reset_index()[DECISION_METRIC].idxmax()]]
best_knn_2 = knn_results_2.iloc[[
    knn_results_2.reset_index()[DECISION_METRIC].idxmax()]]
best_knn_3 = knn_results_3.iloc[[
    knn_results_3.reset_index()[DECISION_METRIC].idxmax()]]

display(best_knn_1, best_knn_2, best_knn_3)
# Out:
#                           f1_score  roc_auc_score  roc_auc_score_var  \
# n_neighbors oversampling
# 8           True          0.289807       0.594597           0.001138
#
#                           accuracy_score  explained_variance_score
# n_neighbors oversampling
# 8           True                    0.52                 -1.685161
#                           f1_score  roc_auc_score  roc_auc_score_var  \
# n_neighbors oversampling
# 14          True           0.29333       0.512004            0.00066
#
#                           accuracy_score  explained_variance_score
# n_neighbors oversampling
# 14          True                0.362366                 -1.320155
#                           f1_score  roc_auc_score  roc_auc_score_var  \
# n_neighbors oversampling
# 3           False         0.533595       0.592244           0.000838
#
#                           accuracy_score  explained_variance_score
# n_neighbors oversampling
# 3           False                0.59939                 -0.602851

# %% [markdown]
# #### 4. Support Vector Classifier

# %%
svc_results = hyperparameter_tuning_cv(model='svc', data=X_no, labels=y_no.Label, cv_k=CV_K,
                                       params=SVC_PARAMS)

display(svc_results)
# Out:
#                            f1_score  roc_auc_score  roc_auc_score_var  \
# kernel gamma oversampling
# linear 0.10  True          0.417668       0.580634           0.000225
#              False         0.000000       0.500000           0.000000
# rbf    0.10  True          0.103556       0.510096           0.000071
#              False         0.013819       0.501773           0.000008
# linear 0.01  True          0.417668       0.580634           0.000225
#              False         0.000000       0.500000           0.000000
# rbf    0.01  True          0.388714       0.563986           0.000319
#              False         0.001515       0.500382           0.000001
#
#                            accuracy_score  explained_variance_score
# kernel gamma oversampling
# linear 0.10  True                0.574900                 -0.981022
#              False               0.742570                  0.000000
# rbf    0.10  True                0.727510                 -0.192766
#              False               0.741767                 -0.015795
# linear 0.01  True                0.574900                 -0.981022
#              False               0.742570                  0.000000
# rbf    0.01  True                0.594578                 -1.004970
#              False               0.742771                  0.000493

# %%
# Best model parameters

best_svc = svc_results.iloc[[
    svc_results.reset_index()[DECISION_METRIC].idxmax()]]

display(best_svc)
# Out:
#                            f1_score  roc_auc_score  roc_auc_score_var  \
# kernel gamma oversampling
# linear 0.1   True          0.417668       0.580634           0.000225
#
#                            accuracy_score  explained_variance_score
# kernel gamma oversampling
# linear 0.1   True                  0.5749                 -0.981022

# %%
svc_results_1 = hyperparameter_tuning_cv(
    model='svc', data=X_no_e_1, labels=y_no_e_1, cv_k=CV_K, params=SVC_PARAMS)
svc_results_2 = hyperparameter_tuning_cv(
    model='svc', data=X_no_e_2, labels=y_no_e_2, cv_k=CV_K, params=SVC_PARAMS)
svc_results_3 = hyperparameter_tuning_cv(
    model='svc', data=X_no_e_3, labels=y_no_e_3, cv_k=CV_K, params=SVC_PARAMS)

# %%
best_svc_1 = svc_results_1.iloc[[
    svc_results_1.reset_index()[DECISION_METRIC].idxmax()]]
best_svc_2 = svc_results_2.iloc[[
    svc_results_2.reset_index()[DECISION_METRIC].idxmax()]]
best_svc_3 = svc_results_3.iloc[[
    svc_results_3.reset_index()[DECISION_METRIC].idxmax()]]


display(best_svc_1, best_svc_2, best_svc_3)
# Out:
#                            f1_score  roc_auc_score  roc_auc_score_var  \
# kernel gamma oversampling
# linear 0.1   True          0.357222        0.64935           0.001029
#
#                            accuracy_score  explained_variance_score
# kernel gamma oversampling
# linear 0.1   True                0.725333                 -1.107013
#                            f1_score  roc_auc_score  roc_auc_score_var  \
# kernel gamma oversampling
# rbf    0.01  True          0.270169       0.535135           0.000972
#
#                            accuracy_score  explained_variance_score
# kernel gamma oversampling
# rbf    0.01  True                0.620968                 -1.404434
#                            f1_score  roc_auc_score  roc_auc_score_var  \
# kernel gamma oversampling
# rbf    0.01  False         0.548118       0.627483           0.002297
#
#                            accuracy_score  explained_variance_score
# kernel gamma oversampling
# rbf    0.01  False               0.639024                 -0.401033

# %% [markdown]
# #### 5. Naive Bayes Classifier

# %%
nb_results = hyperparameter_tuning_cv(model='naive_bayes', data=X_no, labels=y_no.Label, cv_k=CV_K,
                                      params=NAIVE_BAYES_PARAMS)

display(nb_results)
# Out:
#               f1_score  roc_auc_score  roc_auc_score_var  accuracy_score  \
# oversampling
# True          0.424048       0.590753           0.000406        0.594378
# False         0.371778       0.565549           0.000211        0.631325
#
#               explained_variance_score
# oversampling
# True                         -0.908551
# False                        -0.866906

# %%
# Best model parameters
best_nb = nb_results.iloc[[nb_results.reset_index()[DECISION_METRIC].idxmax()]]

display(best_nb)
# Out:
#               f1_score  roc_auc_score  roc_auc_score_var  accuracy_score  \
# oversampling
# True          0.424048       0.590753           0.000406        0.594378
#
#               explained_variance_score
# oversampling
# True                         -0.908551

# %%
nb_results_1 = hyperparameter_tuning_cv(
    model='naive_bayes', data=X_no_e_1, labels=y_no_e_1, cv_k=CV_K, params=NAIVE_BAYES_PARAMS)
nb_results_2 = hyperparameter_tuning_cv(
    model='naive_bayes', data=X_no_e_2, labels=y_no_e_2, cv_k=CV_K, params=NAIVE_BAYES_PARAMS)
nb_results_3 = hyperparameter_tuning_cv(
    model='naive_bayes', data=X_no_e_3, labels=y_no_e_3, cv_k=CV_K, params=NAIVE_BAYES_PARAMS)

# %%
display(nb_results_1, nb_results_2, nb_results_3)
# Out:
#               f1_score  roc_auc_score  roc_auc_score_var  accuracy_score  \
# oversampling
# True          0.292628       0.594836           0.001683        0.641333
# False         0.345589       0.639572           0.002246        0.730667
#
#               explained_variance_score
# oversampling
# True                         -1.561275
# False                        -1.093321
#               f1_score  roc_auc_score  roc_auc_score_var  accuracy_score  \
# oversampling
# True          0.313021       0.572682           0.001722        0.622581
# False         0.274414       0.538965           0.001453        0.634409
#
#               explained_variance_score
# oversampling
# True                         -1.315060
# False                        -1.348454
#               f1_score  roc_auc_score  roc_auc_score_var  accuracy_score  \
# oversampling
# True          0.534245       0.605296           0.004936        0.615244
# False         0.508148       0.591700           0.003570        0.604268
#
#               explained_variance_score
# oversampling
# True                         -0.510861
# False                        -0.540589

# %%
best_nb_1 = nb_results_1.iloc[[
    nb_results_1.reset_index()[DECISION_METRIC].idxmax()]]
best_nb_2 = nb_results_2.iloc[[
    nb_results_2.reset_index()[DECISION_METRIC].idxmax()]]
best_nb_3 = nb_results_3.iloc[[
    nb_results_3.reset_index()[DECISION_METRIC].idxmax()]]

display(best_nb_1, best_nb_2, best_nb_3)
# Out:
#               f1_score  roc_auc_score  roc_auc_score_var  accuracy_score  \
# oversampling
# False         0.345589       0.639572           0.002246        0.730667
#
#               explained_variance_score
# oversampling
# False                        -1.093321
#               f1_score  roc_auc_score  roc_auc_score_var  accuracy_score  \
# oversampling
# True          0.313021       0.572682           0.001722        0.622581
#
#               explained_variance_score
# oversampling
# True                          -1.31506
#               f1_score  roc_auc_score  roc_auc_score_var  accuracy_score  \
# oversampling
# True          0.534245       0.605296           0.004936        0.615244
#
#               explained_variance_score
# oversampling
# True                         -0.510861

# %% [markdown]
# #### 6. Decision Tree

# %%
dt_results = hyperparameter_tuning_cv(model='decision_tree', data=X_no, labels=y_no.Label, cv_k=CV_K,
                                      params=DECISION_TREE_PARAMS)

display(dt_results)
# Out:
#                         f1_score  roc_auc_score  roc_auc_score_var  \
# max_depth oversampling
# 3         True          0.404831       0.569247           0.000326
#           False         0.096164       0.512204           0.000262
# 5         True          0.396275       0.551871           0.000761
#           False         0.164875       0.509275           0.000240
# 7         True          0.379006       0.540550           0.000710
#           False         0.207344       0.509992           0.000627
#
#                         accuracy_score  explained_variance_score
# max_depth oversampling
# 3         True                0.566064                 -0.991978
#           False               0.731928                 -0.155099
# 5         True                0.526104                 -1.081523
#           False               0.699197                 -0.448124
# 7         True                0.535341                 -1.142755
#           False               0.675502                 -0.636082

# %%
# Best model parameters

best_dt = dt_results.iloc[[dt_results.reset_index()[DECISION_METRIC].idxmax()]]

display(best_dt)
# Out:
#                         f1_score  roc_auc_score  roc_auc_score_var  \
# max_depth oversampling
# 3         True          0.404831       0.569247           0.000326
#
#                         accuracy_score  explained_variance_score
# max_depth oversampling
# 3         True                0.566064                 -0.991978

# %%
dt_results_1 = hyperparameter_tuning_cv(
    model='decision_tree', data=X_no_e_1, labels=y_no_e_1, cv_k=CV_K, params=DECISION_TREE_PARAMS)
dt_results_2 = hyperparameter_tuning_cv(
    model='decision_tree', data=X_no_e_2, labels=y_no_e_2, cv_k=CV_K, params=DECISION_TREE_PARAMS)
dt_results_3 = hyperparameter_tuning_cv(
    model='decision_tree', data=X_no_e_3, labels=y_no_e_3, cv_k=CV_K, params=DECISION_TREE_PARAMS)

# %%
best_dt_1 = dt_results_1.iloc[[
    dt_results_1.reset_index()[DECISION_METRIC].idxmax()]]
best_dt_2 = dt_results_2.iloc[[
    dt_results_2.reset_index()[DECISION_METRIC].idxmax()]]
best_dt_3 = dt_results_3.iloc[[
    dt_results_3.reset_index()[DECISION_METRIC].idxmax()]]

display(best_dt_1, best_dt_2, best_dt_3)
# Out:
#                         f1_score  roc_auc_score  roc_auc_score_var  \
# max_depth oversampling
# 3         True          0.303163       0.609033           0.001935
#
#                         accuracy_score  explained_variance_score
# max_depth oversampling
# 3         True                   0.632                 -1.499282
#                         f1_score  roc_auc_score  roc_auc_score_var  \
# max_depth oversampling
# 7         True          0.256772       0.519293           0.001504
#
#                         accuracy_score  explained_variance_score
# max_depth oversampling
# 7         True                 0.59086                 -1.519629
#                         f1_score  roc_auc_score  roc_auc_score_var  \
# max_depth oversampling
# 3         False          0.53443       0.608163           0.001945
#
#                         accuracy_score  explained_variance_score
# max_depth oversampling
# 3         False               0.617073                 -0.484887

# %% [markdown]
# #### 7. Random Forest

# %%
rf_results = hyperparameter_tuning_cv(model='random_forest', data=X_no, labels=y_no.Label, cv_k=CV_K,
                                      params=RANDOM_FOREST_PARAMS)

display(rf_results)
# Out:
#                                      f1_score  roc_auc_score  \
# max_depth n_estimators oversampling
# 3         3            True          0.390547       0.556813
#                        False         0.056887       0.505777
#           5            True          0.405400       0.572247
#                        False         0.025050       0.501931
#           7            True          0.395280       0.561158
#                        False         0.003207       0.497829
# 5         3            True          0.386708       0.558077
#                        False         0.106147       0.507121
#           5            True          0.406548       0.578107
#                        False         0.083850       0.504977
#           7            True          0.399959       0.572612
#                        False         0.060189       0.504037
# 7         3            True          0.376487       0.549898
#                        False         0.170252       0.510972
#           5            True          0.378825       0.557774
#                        False         0.122195       0.507102
#           7            True          0.386689       0.566497
#                        False         0.116983       0.511357
#
#                                      roc_auc_score_var  accuracy_score  \
# max_depth n_estimators oversampling
# 3         3            True                   0.000842        0.559237
#                        False                  0.000080        0.735542
#           5            True                   0.000396        0.580924
#                        False                  0.000041        0.738554
#           7            True                   0.000323        0.566064
#                        False                  0.000022        0.738554
# 5         3            True                   0.000185        0.577912
#                        False                  0.000264        0.721687
#           5            True                   0.000266        0.599598
#                        False                  0.000111        0.726104
#           7            True                   0.000420        0.598394
#                        False                  0.000064        0.732129
# 7         3            True                   0.000341        0.573092
#                        False                  0.000110        0.699598
#           5            True                   0.000926        0.596185
#                        False                  0.000149        0.715261
#           7            True                   0.000670        0.609237
#                        False                  0.000051        0.724900
#
#                                      explained_variance_score
# max_depth n_estimators oversampling
# 3         3            True                         -1.064080
#                        False                        -0.096212
#           5            True                         -1.001967
#                        False                        -0.050277
#           7            True                         -1.052764
#                        False                        -0.033408
# 5         3            True                         -1.046348
#                        False                        -0.237425
#           5            True                         -0.958463
#                        False                        -0.188749
#           7            True                         -0.976649
#                        False                        -0.124284
# 7         3            True                         -1.079854
#                        False                        -0.447623
#           5            True                         -1.013968
#                        False                        -0.299699
#           7            True                         -0.964089
#                        False                        -0.222993

# %%
# Best model parameters

best_rf = rf_results.iloc[[rf_results.reset_index()[DECISION_METRIC].idxmax()]]

display(best_rf)
# Out:
#                                      f1_score  roc_auc_score  \
# max_depth n_estimators oversampling
# 5         5            True          0.406548       0.578107
#
#                                      roc_auc_score_var  accuracy_score  \
# max_depth n_estimators oversampling
# 5         5            True                   0.000266        0.599598
#
#                                      explained_variance_score
# max_depth n_estimators oversampling
# 5         5            True                         -0.958463

# %%
rf_results_1 = hyperparameter_tuning_cv(
    model='random_forest', data=X_no_e_1, labels=y_no_e_1, cv_k=CV_K, params=RANDOM_FOREST_PARAMS)
rf_results_2 = hyperparameter_tuning_cv(
    model='random_forest', data=X_no_e_2, labels=y_no_e_2, cv_k=CV_K, params=RANDOM_FOREST_PARAMS)
rf_results_3 = hyperparameter_tuning_cv(
    model='random_forest', data=X_no_e_3, labels=y_no_e_3, cv_k=CV_K, params=RANDOM_FOREST_PARAMS)

# %%
best_rf_1 = rf_results_1.iloc[[
    rf_results_1.reset_index()[DECISION_METRIC].idxmax()]]
best_rf_2 = rf_results_2.iloc[[
    rf_results_2.reset_index()[DECISION_METRIC].idxmax()]]
best_rf_3 = rf_results_3.iloc[[
    rf_results_3.reset_index()[DECISION_METRIC].idxmax()]]

display(best_rf_1, best_rf_2, best_rf_3)
# Out:
#                                      f1_score  roc_auc_score  \
# max_depth n_estimators oversampling
# 7         5            True          0.348002       0.636495
#
#                                      roc_auc_score_var  accuracy_score  \
# max_depth n_estimators oversampling
# 7         5            True                   0.002827        0.751333
#
#                                      explained_variance_score
# max_depth n_estimators oversampling
# 7         5            True                         -0.985198
#                                      f1_score  roc_auc_score  \
# max_depth n_estimators oversampling
# 3         5            True          0.262596       0.520728
#
#                                      roc_auc_score_var  accuracy_score  \
# max_depth n_estimators oversampling
# 3         5            True                   0.002127        0.569892
#
#                                      explained_variance_score
# max_depth n_estimators oversampling
# 3         5            True                         -1.566752
#                                      f1_score  roc_auc_score  \
# max_depth n_estimators oversampling
# 3         7            False         0.515253       0.592027
#
#                                      roc_auc_score_var  accuracy_score  \
# max_depth n_estimators oversampling
# 3         7            False                  0.001705        0.603049
#
#                                      explained_variance_score
# max_depth n_estimators oversampling
# 3         7            False                        -0.564172

# %% [markdown]
# #### 8. Gradient Boosting

# %%
gb_results = hyperparameter_tuning_cv(model='gradient_boosting', data=X_no, labels=y_no.Label, cv_k=CV_K,
                                      params=GRADIENT_BOOSTING_PARAMS)

display(gb_results)
# Out:
#                                      f1_score  roc_auc_score  \
# max_depth n_estimators oversampling
# 3         3            True          0.412015       0.575793
#                        False         0.000000       0.500000
#           5            True          0.407932       0.573475
#                        False         0.005973       0.500984
#           7            True          0.408981       0.576602
#                        False         0.010347       0.501727
# 5         3            True          0.386080       0.554641
#                        False         0.000000       0.500000
#           5            True          0.389426       0.561987
#                        False         0.016087       0.502447
#           7            True          0.387377       0.563420
#                        False         0.035052       0.505395
# 7         3            True          0.363658       0.536808
#                        False         0.003255       0.500403
#           5            True          0.375362       0.554161
#                        False         0.034671       0.503306
#           7            True          0.372877       0.556590
#                        False         0.054197       0.504269
#
#                                      roc_auc_score_var  accuracy_score  \
# max_depth n_estimators oversampling
# 3         3            True                   0.000299        0.572691
#                        False                  0.000000        0.742570
#           5            True                   0.000291        0.576506
#                        False                  0.000003        0.742570
#           7            True                   0.000333        0.586345
#                        False                  0.000009        0.742570
# 5         3            True                   0.000798        0.567871
#                        False                  0.000000        0.742570
#           5            True                   0.000491        0.584940
#                        False                  0.000024        0.742169
#           7            True                   0.000593        0.595783
#                        False                  0.000061        0.741566
# 7         3            True                   0.000466        0.560643
#                        False                  0.000005        0.742369
#           5            True                   0.000408        0.592169
#                        False                  0.000047        0.738153
#           7            True                   0.000342        0.605020
#                        False                  0.000128        0.734337
#
#                                      explained_variance_score
# max_depth n_estimators oversampling
# 3         3            True                         -0.994706
#                        False                         0.000000
#           5            True                         -1.001980
#                        False                        -0.004321
#           7            True                         -0.982395
#                        False                        -0.007499
# 5         3            True                         -1.074705
#                        False                         0.000000
#           5            True                         -1.024128
#                        False                        -0.014929
#           7            True                         -1.000105
#                        False                        -0.033214
# 7         3            True                         -1.131829
#                        False                        -0.003534
#           5            True                         -1.032135
#                        False                        -0.059849
#           7            True                         -0.995450
#                        False                        -0.103306

# %%
# Best model parameters

best_gb = gb_results.iloc[[gb_results.reset_index()[DECISION_METRIC].idxmax()]]

display(best_gb)
# Out:
#                                      f1_score  roc_auc_score  \
# max_depth n_estimators oversampling
# 3         7            True          0.408981       0.576602
#
#                                      roc_auc_score_var  accuracy_score  \
# max_depth n_estimators oversampling
# 3         7            True                   0.000333        0.586345
#
#                                      explained_variance_score
# max_depth n_estimators oversampling
# 3         7            True                         -0.982395

# %%
gb_results_1 = hyperparameter_tuning_cv(
    model='gradient_boosting', data=X_no_e_1, labels=y_no_e_1, cv_k=CV_K, params=GRADIENT_BOOSTING_PARAMS)
gb_results_2 = hyperparameter_tuning_cv(
    model='gradient_boosting', data=X_no_e_2, labels=y_no_e_2, cv_k=CV_K, params=GRADIENT_BOOSTING_PARAMS)
gb_results_3 = hyperparameter_tuning_cv(
    model='gradient_boosting', data=X_no_e_3, labels=y_no_e_3, cv_k=CV_K, params=GRADIENT_BOOSTING_PARAMS)

# %%
best_gb_1 = gb_results_1.iloc[[
    gb_results_1.reset_index()[DECISION_METRIC].idxmax()]]
best_gb_2 = gb_results_2.iloc[[
    gb_results_2.reset_index()[DECISION_METRIC].idxmax()]]
best_gb_3 = gb_results_3.iloc[[
    gb_results_3.reset_index()[DECISION_METRIC].idxmax()]]
display(best_gb_1, best_gb_2, best_gb_3)
# Out:
#                                      f1_score  roc_auc_score  \
# max_depth n_estimators oversampling
# 3         7            True          0.326183        0.62804
#
#                                      roc_auc_score_var  accuracy_score  \
# max_depth n_estimators oversampling
# 3         7            True                   0.000817        0.684667
#
#                                      explained_variance_score
# max_depth n_estimators oversampling
# 3         7            True                         -1.321611
#                                      f1_score  roc_auc_score  \
# max_depth n_estimators oversampling
# 3         3            True          0.262925       0.521432
#
#                                      roc_auc_score_var  accuracy_score  \
# max_depth n_estimators oversampling
# 3         3            True                   0.001743        0.573656
#
#                                      explained_variance_score
# max_depth n_estimators oversampling
# 3         3            True                         -1.529917
#                                      f1_score  roc_auc_score  \
# max_depth n_estimators oversampling
# 3         5            True          0.578662       0.617959
#
#                                      roc_auc_score_var  accuracy_score  \
# max_depth n_estimators oversampling
# 3         5            True                   0.001273        0.620732
#
#                                      explained_variance_score
# max_depth n_estimators oversampling
# 3         5            True                         -0.516263

# %% [markdown]
# ### Results

# %%
# display('logistic', best_log)
# display('lda', best_lda)
# display('knn', best_knn)
# display('svc', best_svc)
# display('naive_bayes', best_nb)
# display('decision_tree', best_dt)
# display('random_forest', best_rf)
# display('gradient_boosting', best_gb)

# %%
weighted_average = (
    np.array([len(X_no_e_1), len(X_no_e_2), len(X_no_e_3)]) / len(X_no_e))

e_log = np.sum(pd.concat([best_log_1, best_log_2, best_log_3]
                         ).roc_auc_score.values * weighted_average)
e_lda = np.sum(pd.concat([best_lda_1, best_lda_2, best_lda_3]
                         ).roc_auc_score.values * weighted_average)
e_knn = np.sum(pd.concat([best_knn_1, best_knn_2, best_knn_3]
                         ).roc_auc_score.values * weighted_average)
e_svc = np.sum(pd.concat([best_svc_1, best_svc_2, best_svc_3]
                         ).roc_auc_score.values * weighted_average)
e_nb = np.sum(pd.concat([best_nb_1, best_nb_2, best_nb_3]
                        ).roc_auc_score.values * weighted_average)
e_dt = np.sum(pd.concat([best_dt_1, best_dt_2, best_dt_3]
                        ).roc_auc_score.values * weighted_average)
e_rf = np.sum(pd.concat([best_rf_1, best_rf_2, best_rf_3]
                        ).roc_auc_score.values * weighted_average)
e_gb = np.sum(pd.concat([best_gb_1, best_gb_2, best_gb_3]
                        ).roc_auc_score.values * weighted_average)

# %%
# Results expert features
# First row is Expert 1, second Expert 2, third Expert 3
# display('logistic', pd.concat([best_log_1,best_log_2,best_log_3]))
# display('lda', pd.concat([best_lda_1,best_lda_2,best_lda_3]))
# display('knn', pd.concat([best_knn_1,best_knn_2,best_knn_3]))
display('svc', pd.concat([best_svc_1, best_svc_2, best_svc_3]))
display('naive_bayes', pd.concat([best_nb_1, best_nb_2, best_nb_3]))
# display('decision_tree', pd.concat([best_dt_1,best_dt_2,best_dt_3]))
# display('random_forest', pd.concat([best_rf_1,best_rf_2,best_rf_3]))
# display('gradient_boosting', pd.concat([best_gb_1,best_gb_2,best_gb_3]))
# Out:
# 'svc'
#                            f1_score  roc_auc_score  roc_auc_score_var  \
# kernel gamma oversampling
# linear 0.10  True          0.357222       0.649350           0.001029
# rbf    0.01  True          0.270169       0.535135           0.000972
#              False         0.548118       0.627483           0.002297
#
#                            accuracy_score  explained_variance_score
# kernel gamma oversampling
# linear 0.10  True                0.725333                 -1.107013
# rbf    0.01  True                0.620968                 -1.404434
#              False               0.639024                 -0.401033
# 'naive_bayes'
#               f1_score  roc_auc_score  roc_auc_score_var  accuracy_score  \
# oversampling
# False         0.345589       0.639572           0.002246        0.730667
# True          0.313021       0.572682           0.001722        0.622581
# True          0.534245       0.605296           0.004936        0.615244
#
#               explained_variance_score
# oversampling
# False                        -1.093321
# True                         -1.315060
# True                         -0.510861

# %%
results = pd.DataFrame(data={'models': ['logistic', 'lda', 'knn', 'svc', 'naive_bayes', 'decision_tree',
                                        'random_forest', 'gradient_boosting'],
                             'auc_best': [best_log.roc_auc_score.values[0], best_lda.roc_auc_score.values[0],
                                          best_knn.roc_auc_score.values[0], best_svc.roc_auc_score.values[0],
                                          best_nb.roc_auc_score.values[0], best_dt.roc_auc_score.values[0],
                                          best_rf.roc_auc_score.values[0], best_gb.roc_auc_score.values[0]],
                             'auc_expert_weighted': [e_log, e_lda, e_knn, e_svc, e_nb, e_dt, e_rf, e_gb]})

display(results)
# Out:
#               models  auc_best  auc_expert_weighted
# 0           logistic  0.583838             0.579833
# 1                lda  0.582798             0.578009
# 2                knn  0.558399             0.563058
# 3                svc  0.580634             0.599633
# 4        naive_bayes  0.590753             0.603415
# 5      decision_tree  0.569247             0.575318
# 6      random_forest  0.578107             0.578789
# 7  gradient_boosting  0.576602             0.585021

# %% [markdown]
# ### Conclusions

# %%
# Save dataframe
results.to_pickle("results_no_seg_no_metadata.pkl")

# %%
results.mean(axis=0)
# Out:
# auc_best               0.577547
# auc_expert_weighted    0.582885
# dtype: float64

# %%
results.loc[results['auc_best'].argmax()]
# Out:
# models                 naive_bayes
# auc_best                  0.590753
# auc_expert_weighted       0.603415
# Name: 4, dtype: object

# %%
results.loc[results['auc_expert_weighted'].argmax()]
# Out:
# models                 naive_bayes
# auc_best                  0.590753
# auc_expert_weighted       0.603415
# Name: 4, dtype: object
